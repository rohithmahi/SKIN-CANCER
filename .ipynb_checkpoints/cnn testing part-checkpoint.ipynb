# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import glob
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
data_dir_train = pathlib.Path(r"D:\PROJECTS\Rohith\skin cancer cnn\Skin cancer ISIC The International Skin Imaging Collaboration\Train")
data_dir_test = pathlib.Path(r"D:\PROJECTS\Rohith\skin cancer cnn\Skin cancer ISIC The International Skin Imaging Collaboration\Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
batch_size = 32
img_height = 180
img_width = 180
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import cv2


# Load the image file
img = image.load_img(r"D:\PROJECTS\Rohith\skin cancer cnn\Skin cancer ISIC The International Skin Imaging Collaboration\Testing\ISIC_0024383.jpg", target_size=(img_height, img_width))
plt.imshow(img)
# Convert the image to a numpy array
x = image.img_to_array(img)

# Expand the dimensions of the array to match the model input
x = np.expand_dims(x, axis=0)

# Make predictions on the image
preds = model.predict(x)

# Get the class with the highest probability
pred_class = class_names[np.argmax(preds[0])]

# Get the class probability
pred_prob = preds[0][np.argmax(preds[0])]

print("Class: ", pred_class)
#print("Probability: ", pred_prob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      13 x = np.expand_dims(x, axis=0)
#      15 # Make predictions on the image
# ---> 16 preds = model.predict(x)
#      18 # Get the class with the highest probability
#      19 pred_class = class_names[np.argmax(preds[0])]
#
# NameError: name 'model' is not defined
